# %%
import pandas as pd
import numpy as np

# %%
data_may_04_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190504.txt")
data_may_11_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190511.txt")
#data_may_18_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190518.txt")
#data_may_25_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190525.txt")
#data_may_05_18 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_180505.txt")
#data_may_12_18 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_180512.txt")
#data_may_19_18 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_180519.txt")
#data_may_26_18 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_180526.txt")

# %%
all_data = pd.concat([data_may_04_19, data_may_11_19], ignore_index=True)
#all_data = pd.concat([data_may_04_19, data_may_11_19, data_may_18_19, data_may_25_19, data_may_05_18, data_may_12_18, data_may_19_18, data_may_26_18])
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410945 entries, 0 to 410944
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   410945 non-null  object
#  1   UNIT                                                                  410945 non-null  object
#  2   SCP                                                                   410945 non-null  object
#  3   STATION                                                               410945 non-null  object
#  4   LINENAME                                                              410945 non-null  object
#  5   DIVISION                                                              410945 non-null  object
# ...

# %%
all_data['datetime'] = pd.to_datetime(all_data['DATE'] + ' ' + all_data['TIME'])

# %%
all_data['turnstile'] = all_data['C/A'] + all_data['UNIT'] + all_data['SCP'] + all_data['STATION']

# %%
all_data.sort_values(by = ['turnstile', 'datetime'], inplace = True)

# %%
all_data.tail(50)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 206849  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206850  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206851  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206852  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206853  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206854  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206855  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206856  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 410903  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/04/2019
# 410904  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/04/2019
# 410905  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/04/2019
# ...

# %%
#all_data['first_datetime'] = all_data.groupby('turnstile').min('datetime')

# I used 'First' as fillna so it would be easier to see how many it would change, will sub in 0 later
all_data['entries_diff'] = all_data.groupby('turnstile')['ENTRIES'].diff()
#all_data.sort_values(['entries_diff'], ascending = False).head(20)
#all_data.sort_values(['turnstile', 'datetime'])
#all_data.iloc[143675:143700]
#all_data[all_data['turnstile'] == 'N196R28500-05-01FAR ROCKAWAY']
#all_data[all_data['datetime'] == '2019-05-03 16:00:00']

#all_data.reset_index(inplace = True)

#all_data['daily_entries']

all_data.groupby(['turnstile','DATE']).sum('entries_diff')
# Out:
#                                              index   ENTRIES  \
# turnstile                      DATE
# A002R05102-00-0059 ST          04/27/2019       15  42212783
#                                04/28/2019       51  42217534
#                                04/29/2019       87  42222537
#                                04/30/2019      123  42231580
#                                05/01/2019      159  42240617
# ...                                            ...       ...
# TRAM2R46900-05-01RIT-ROOSEVELT 05/06/2019  2465505     33324
#                                05/07/2019  2465541     33324
#                                05/08/2019  2465577     33324
#                                05/09/2019  2465613     33324
#                                05/10/2019  2465649     33324
#
#                                            EXITS                                                                 \
# turnstile                      DATE
# ...

# %%
# check to see if number of distinct turnstiles matches the number that were filled in as 'First'
all_data['turnstile'].nunique()
# Number of distinct turnstiles matches number of 'First' entries
# Out:
# 4853

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410945 entries, 0 to 410944
# Data columns (total 15 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   index                                                                 410945 non-null  int64
#  1   C/A                                                                   410945 non-null  object
#  2   UNIT                                                                  410945 non-null  object
#  3   SCP                                                                   410945 non-null  object
#  4   STATION                                                               410945 non-null  object
#  5   LINENAME                                                              410945 non-null  object
# ...

# %%
all_data[all_data['datetime'] == '2019-05-03 16:00:00']
# Out:
#          index   C/A  UNIT       SCP     STATION LINENAME DIVISION  \
# 42          42  A002  R051  02-00-00       59 ST  NQR456W      BMT
# 128         86  A002  R051  02-00-01       59 ST  NQR456W      BMT
# 214        130  A002  R051  02-03-00       59 ST  NQR456W      BMT
# 300        174  A002  R051  02-03-01       59 ST  NQR456W      BMT
# 386        218  A002  R051  02-03-02       59 ST  NQR456W      BMT
# ...        ...   ...   ...       ...         ...      ...      ...
# 409056  205362  S101  R070  00-00-08  ST. GEORGE        1      SRT
# 409156  205417  S101  R070  00-03-00  ST. GEORGE        1      SRT
# 409256  205472  S101  R070  00-03-01  ST. GEORGE        1      SRT
# 409356  205527  S101  R070  00-03-02  ST. GEORGE        1      SRT
# 409456  205582  S101  R070  00-03-03  ST. GEORGE        1      SRT
#
#               DATE      TIME     DESC  ENTRIES  \
# 42      05/03/2019  16:00:00  REGULAR  7043403
# 128     05/03/2019  16:00:00  REGULAR  6274905
# ...

# %%
all_data['DESC'].unique()
# Out:
# array(['REGULAR', 'RECOVR AUD'], dtype=object)
