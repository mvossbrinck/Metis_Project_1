# %%
import pandas as pd
import numpy as np

# %%
data_may_04_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190504.txt")
data_may_11_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190511.txt")
data_may_18_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190518.txt")
data_may_25_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190525.txt")
data_jun_06_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190601.txt")
data_jun_08_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190608.txt")
data_jun_15_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190615.txt")
data_apr_27_19 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190427.txt")

# %%
#all_data = pd.concat([data_may_04_19, data_may_11_19], ignore_index=True)
all_data = pd.concat([data_may_04_19, data_may_11_19, data_may_18_19, data_may_25_19, data_jun_06_19, data_jun_08_19, data_jun_15_19, data_apr_27_19], ignore_index=True)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640586 entries, 0 to 1640585
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count    Dtype
# ---  ------                                                                --------------    -----
#  0   C/A                                                                   1640586 non-null  object
#  1   UNIT                                                                  1640586 non-null  object
#  2   SCP                                                                   1640586 non-null  object
#  3   STATION                                                               1640586 non-null  object
#  4   LINENAME                                                              1640586 non-null  object
#  5   DIVISION                                                              1640586 non-null  object
# ...

# %%
# Add new variables and sort
all_data = all_data[all_data['DESC'] == 'REGULAR']
all_data['datetime'] = pd.to_datetime(all_data['DATE'] + ' ' + all_data['TIME'])
all_data['turnstile'] = all_data['C/A'] + all_data['UNIT'] + all_data['SCP'] + all_data['STATION']
all_data.sort_values(by = ['turnstile', 'datetime'], inplace = True)

# %%
# Clean entry and exit data
all_data.rename(columns={'EXITS                                                               ': 'EXITS'}, inplace=True)
all_data['entries_diff'] = all_data.groupby('turnstile')['ENTRIES'].diff()
all_data['exits_diff'] = all_data.groupby('turnstile')['EXITS'].diff()
indexNames = all_data[(all_data['entries_diff'] <0 ) | (all_data['exits_diff'] < 0)].index
all_data_clean = all_data.drop(indexNames)
indexNames = all_data_clean[(all_data_clean['entries_diff'] > 10000 ) | (all_data_clean['exits_diff'] > 10000)].index
all_data_clean = all_data_clean.drop(indexNames)
all_data_clean.groupby(['STATION', 'DATE']).sum(['entries_diff', 'exits_diff']).sort_values('entries_diff', ascending = False)

all_data_clean['total_foot_traffic'] = all_data_clean['entries_diff'] + all_data_clean['exits_diff']
all_data_clean['day_of_week'] = all_data_clean['datetime'].dt.day_name()
all_data_clean.head(25)

# %%
df_weekday = all_data_clean.groupby(['STATION']).sum(['total_foot_traffic'])
df_weekday.sort_values(['total_foot_traffic'], ascending = False).head(50)
# Out:
#                        ENTRIES          EXITS  entries_diff  exits_diff  \
# STATION
# 34 ST-PENN STA   1285998395563   993084959313     8142689.0   7459363.0
# GRD CNTRL-42 ST   485689607972   384323764199     7017451.0   6118921.0
# 34 ST-HERALD SQ   715776946321   646136549311     5692305.0   5387359.0
# 14 ST-UNION SQ    240992656454   126495142802     5091185.0   4716003.0
# TIMES SQ-42 ST   1408578778747  1095028029137     4973233.0   4669469.0
# 23 ST            1225237560131   967274027281     5409137.0   3918826.0
# FULTON ST        1539172005149  1567829710034     4625623.0   3920934.0
# 42 ST-PORT AUTH  1240133395722   875041240187     4561440.0   3912910.0
# 86 ST             175070995042   139138830721     3988041.0   3765742.0
# 125 ST           1109742126684   713957446078     3686351.0   3156528.0
# CANAL ST          786357066665  1242252022881     3612330.0   2934935.0
# 59 ST COLUMBUS   1142321221007  1001502007380     3595815.0   2941061.0
# ...

# %%
# check to see if number of distinct turnstiles matches the number that were filled in as 'First'
all_data['turnstile'].nunique()
# Number of distinct turnstiles matches number of 'First' entries
# Out:
# 4853

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410945 entries, 0 to 410944
# Data columns (total 15 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   index                                                                 410945 non-null  int64
#  1   C/A                                                                   410945 non-null  object
#  2   UNIT                                                                  410945 non-null  object
#  3   SCP                                                                   410945 non-null  object
#  4   STATION                                                               410945 non-null  object
#  5   LINENAME                                                              410945 non-null  object
# ...

# %%
all_data[all_data['datetime'] == '2019-05-03 16:00:00']
# Out:
#          index   C/A  UNIT       SCP     STATION LINENAME DIVISION  \
# 42          42  A002  R051  02-00-00       59 ST  NQR456W      BMT
# 128         86  A002  R051  02-00-01       59 ST  NQR456W      BMT
# 214        130  A002  R051  02-03-00       59 ST  NQR456W      BMT
# 300        174  A002  R051  02-03-01       59 ST  NQR456W      BMT
# 386        218  A002  R051  02-03-02       59 ST  NQR456W      BMT
# ...        ...   ...   ...       ...         ...      ...      ...
# 409056  205362  S101  R070  00-00-08  ST. GEORGE        1      SRT
# 409156  205417  S101  R070  00-03-00  ST. GEORGE        1      SRT
# 409256  205472  S101  R070  00-03-01  ST. GEORGE        1      SRT
# 409356  205527  S101  R070  00-03-02  ST. GEORGE        1      SRT
# 409456  205582  S101  R070  00-03-03  ST. GEORGE        1      SRT
#
#               DATE      TIME     DESC  ENTRIES  \
# 42      05/03/2019  16:00:00  REGULAR  7043403
# 128     05/03/2019  16:00:00  REGULAR  6274905
# ...

# %%
all_data['DESC'].unique()
# Out:
# array(['REGULAR', 'RECOVR AUD'], dtype=object)
